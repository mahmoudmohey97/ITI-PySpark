# %% [markdown]
# ## Task 1 - SQL

# %% [markdown]
# ### Colab and Importings

# %%
# !pwd
! wget https://archive.apache.org/dist/spark/spark-3.0.1/spark-3.0.1-bin-hadoop3.2.tgz

# !tar -xvzf spark-3.0.1-bin-hadoop3.2.tgz
# !pip install findspark

# %%
import os
import findspark

os.environ["SPARK_HOME"] = "/content/spark-3.0.1-bin-hadoop3.2"
findspark.init()

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as f

# %% [markdown]
# ### Build SparkSession:

# %%
spark = SparkSession.builder.appName('Assignment2').getOrCreate()

# %% [markdown]
# ### Read the json file:

# %%
df = spark.read.json('DataFrames_sample.json')

# %% [markdown]
# ### Display the schema:

# %%
df.printSchema()
# Out:
# root
#  |-- D: double (nullable = true)
#  |-- H: double (nullable = true)
#  |-- HDD: string (nullable = true)
#  |-- Id: long (nullable = true)
#  |-- Model: string (nullable = true)
#  |-- RAM: string (nullable = true)
#  |-- ScreenSize: string (nullable = true)
#  |-- W: double (nullable = true)
#  |-- Weight: double (nullable = true)
#  |-- Year: long (nullable = true)

# %% [markdown]
# ### Get all the data when "Model" equal "MacBook Pro":

# %%
df.select('*').where(f.col('model')=="MacBook Pro").show()
# Out:
# +----+----+---------+---+-----------+----+----------+-----+------+----+
# |   D|   H|      HDD| Id|      Model| RAM|ScreenSize|    W|Weight|Year|
# +----+----+---------+---+-----------+----+----------+-----+------+----+
# |9.48|0.61|512GB SSD|  1|MacBook Pro|16GB|       15"|13.75|  4.02|2015|
# +----+----+---------+---+-----------+----+----------+-----+------+----+

# %% [markdown]
# ### Create TempView:

# %%
df.createOrReplaceTempView('json_file')

# %% [markdown]
# ### Display "RAM"column and count "RAM" column:

# %%
spark.sql("""select ram, count(ram) from json_file group by ram""").show()
# Out:
# +----+----------+
# | ram|count(ram)|
# +----+----------+
# |64GB|         1|
# |16GB|         1|
# | 8GB|         2|
# +----+----------+

# %% [markdown]
# ### Get all columns when "Year" column equal "2015"

# %%
spark.sql("""select * from json_file where year == 2015""").show()
# Out:
# +----+----+---------+---+-----------+----+----------+-----+------+----+
# |   D|   H|      HDD| Id|      Model| RAM|ScreenSize|    W|Weight|Year|
# +----+----+---------+---+-----------+----+----------+-----+------+----+
# |9.48|0.61|512GB SSD|  1|MacBook Pro|16GB|       15"|13.75|  4.02|2015|
# +----+----+---------+---+-----------+----+----------+-----+------+----+

# %% [markdown]
# ### Get all when "Model" start with "M":

# %%
spark.sql("""select * from json_file where model like 'M%'""").show()
# Out:
# +----+----+---------+---+-----------+----+----------+-----+------+----+
# |   D|   H|      HDD| Id|      Model| RAM|ScreenSize|    W|Weight|Year|
# +----+----+---------+---+-----------+----+----------+-----+------+----+
# |9.48|0.61|512GB SSD|  1|MacBook Pro|16GB|       15"|13.75|  4.02|2015|
# |7.74|0.52|256GB SSD|  2|    MacBook| 8GB|       12"|11.04|  2.03|2016|
# |8.94|0.68|128GB SSD|  3|MacBook Air| 8GB|     13.3"| 12.8|  2.96|2016|
# +----+----+---------+---+-----------+----+----------+-----+------+----+

# %% [markdown]
# ### Get all data when "Model" column equal "MacBook Pro"

# %%
spark.sql("""select * from json_file where model=='MacBook Pro' """).show()
# Out:
# +----+----+---------+---+-----------+----+----------+-----+------+----+
# |   D|   H|      HDD| Id|      Model| RAM|ScreenSize|    W|Weight|Year|
# +----+----+---------+---+-----------+----+----------+-----+------+----+
# |9.48|0.61|512GB SSD|  1|MacBook Pro|16GB|       15"|13.75|  4.02|2015|
# +----+----+---------+---+-----------+----+----------+-----+------+----+

# %% [markdown]
# ### Get all data with Multiple Conditions when "RAM" column equal "8GB" and "Model" column is "Macbook".

# %%
spark.sql("""select * from json_file where ram = '8GB' and model = 'MacBook' """).show()
# Out:
# +----+----+---------+---+-------+---+----------+-----+------+----+
# |   D|   H|      HDD| Id|  Model|RAM|ScreenSize|    W|Weight|Year|
# +----+----+---------+---+-------+---+----------+-----+------+----+
# |7.74|0.52|256GB SSD|  2|MacBook|8GB|       12"|11.04|  2.03|2016|
# +----+----+---------+---+-------+---+----------+-----+------+----+

# %% [markdown]
# ### Get all data with Multiple Conditions when "D" greater than or equal "8" and "Model" column is "iMac".

# %%
spark.sql("""select * from json_file where d >= 8 and model = 'iMac' """).show()
# Out:
# +---+----+-------+---+-----+----+----------+----+------+----+
# |  D|   H|    HDD| Id|Model| RAM|ScreenSize|   W|Weight|Year|
# +---+----+-------+---+-----+----+----------+----+------+----+
# |8.0|20.3|1TB SSD|  4| iMac|64GB|       27"|25.6|  20.8|2017|
# +---+----+-------+---+-----+----+----------+----+------+----+

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Read "test1" dataset:

# %%
df = spark.read.csv('test1.csv', inferSchema=True, header=True)

# %%
df.show()
# Out:
# +---------+---+----------+------+
# |     Name|age|Experience|Salary|
# +---------+---+----------+------+
# |    Krish| 31|        10| 30000|
# |Sudhanshu| 30|         8| 25000|
# |    Sunny| 29|         4| 20000|
# |     Paul| 24|         3| 20000|
# |   Harsha| 21|         1| 15000|
# |  Shubham| 23|         2| 18000|
# +---------+---+----------+------+

# %% [markdown]
# ### Display Salary of the people less than or equal to 20000

# %%
df.select('Salary').filter(df['Salary'] <= 20000).sort('Salary').show()
# Out:
# +------+
# |Salary|
# +------+
# | 15000|
# | 18000|
# | 20000|
# | 20000|
# +------+

# %% [markdown]
# ### Display Salary of the people less than or equal to 20000 and greater than or equal 15000

# %%
df.select('Salary').where((f.col('Salary' ) >= 15000) & (f.col('Salary') <= 20000)).sort('Salary').show()
# Out:
# +------+
# |Salary|
# +------+
# | 15000|
# | 18000|
# | 20000|
# | 20000|
# +------+

# %% [markdown]
# ## Task 3

# %% [markdown]
# ### Read "test3" dataset:

# %%
df3 = spark.read.csv('test3.csv', inferSchema=True, header=True)

# %% [markdown]
# ### Display dataset

# %%
df3.show()
# Out:
# +---------+------------+------+
# |     Name| Departments|salary|
# +---------+------------+------+
# |    Krish|Data Science| 10000|
# |    Krish|         IOT|  5000|
# |   Mahesh|    Big Data|  4000|
# |    Krish|    Big Data|  4000|
# |   Mahesh|Data Science|  3000|
# |Sudhanshu|Data Science| 20000|
# |Sudhanshu|         IOT| 10000|
# |Sudhanshu|    Big Data|  5000|
# |    Sunny|Data Science| 10000|
# |    Sunny|    Big Data|  2000|
# +---------+------------+------+

# %% [markdown]
# ### Display schema

# %%
df3.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Departments: string (nullable = true)
#  |-- salary: integer (nullable = true)

# %% [markdown]
# ### Group by "Name" column and using sum function on "Name" column

# %%
df3.groupBy('Name').agg(f.sum('Salary')).show()
# Out:
# +---------+-----------+
# |     Name|sum(Salary)|
# +---------+-----------+
# |Sudhanshu|      35000|
# |    Sunny|      12000|
# |    Krish|      19000|
# |   Mahesh|       7000|
# +---------+-----------+

# %% [markdown]
# ### Group by "Name" column and using avg function on "Name" column

# %%
df3.groupBy('Name').agg(f.avg('Salary')).show()
# Out:
# +---------+------------------+
# |     Name|       avg(Salary)|
# +---------+------------------+
# |Sudhanshu|11666.666666666666|
# |    Sunny|            6000.0|
# |    Krish| 6333.333333333333|
# |   Mahesh|            3500.0|
# +---------+------------------+

# %% [markdown]
# ### Group by "Departments" column and using sum function on "Departments" column

# %%
df3.groupBy('Departments').agg(f.sum('Salary')).show()
# Out:
# +------------+-----------+
# | Departments|sum(Salary)|
# +------------+-----------+
# |         IOT|      15000|
# |    Big Data|      15000|
# |Data Science|      43000|
# +------------+-----------+

# %% [markdown]
# ### Group by "Departments" column and using mean function on "Departments" column:

# %%
df3.groupBy('Departments').agg(f.avg('Salary')).show()
# Out:
# +------------+-----------+
# | Departments|avg(Salary)|
# +------------+-----------+
# |         IOT|     7500.0|
# |    Big Data|     3750.0|
# |Data Science|    10750.0|
# +------------+-----------+

# %% [markdown]
# Group by "Departments" column and using count function on "Departments" column:

# %%
df3.groupBy('Departments').agg(f.count('Departments')).show()
# Out:
# +------------+------------------+
# | Departments|count(Departments)|
# +------------+------------------+
# |         IOT|                 2|
# |    Big Data|                 4|
# |Data Science|                 4|
# +------------+------------------+

# %% [markdown]
# ### Apply agg to using sum function get the total of salaries

# %%
df3.select(f.sum('Salary')).show()
# Out:
# +-----------+
# |sum(Salary)|
# +-----------+
# |      73000|
# +-----------+

# %% [markdown]
# ## Task 4

# %% [markdown]
# You've been flown to their headquarters in Ulsan, South Korea, to assist them in accurately estimating the number of crew members a ship will need.

# %% [markdown]
# They're currently building new ships for certain customers, and they'd like you to create a model and utilize it to estimate how many crew members the ships will require.

# %% [markdown]
# Metadata:
# 1. Measurements of ship size
# 2. capacity
# 3. crew
# 4. age for 158 cruise ships.

# %% [markdown]
# It is saved in a csv file for you called "ITI_data.csv". our task is to develop a regression model that will assist in predicting the number of crew members required for future ships. The client also indicated that they have found that particular cruise lines will differ in acceptable crew counts, thus this is most likely an important factor to consider when conducting your investigation.

# %%
crew_df = spark.read.csv('ITI_data.csv', inferSchema=True, header=True)

# %%
crew_df.printSchema()
# Out:
# root
#  |-- Ship_name: string (nullable = true)
#  |-- Cruise_line: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Tonnage: double (nullable = true)
#  |-- passengers: double (nullable = true)
#  |-- length: double (nullable = true)
#  |-- cabins: double (nullable = true)
#  |-- passenger_density: double (nullable = true)
#  |-- crew: double (nullable = true)

# %%
crew_df.show(5)
# Out:
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+
# |  Ship_name|Cruise_line|Age|           Tonnage|passengers|length|cabins|passenger_density|crew|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+
# |    Journey|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|
# |      Quest|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|
# |Celebration|   Carnival| 26|            47.262|     14.86|  7.22|  7.43|             31.8| 6.7|
# |   Conquest|   Carnival| 11|             110.0|     29.74|  9.53| 14.88|            36.99|19.1|
# |    Destiny|   Carnival| 17|           101.353|     26.42|  8.92| 13.21|            38.36|10.0|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+
# only showing top 5 rows

# %%
crew_df.groupBy('Ship_name').agg(f.count('*')).count()
# Out:
# 138

# %%
crew_df.groupBy('Cruise_line').agg(f.count('*')).show()
# Out:
# +-----------------+--------+
# |      Cruise_line|count(1)|
# +-----------------+--------+
# |            Costa|      11|
# |              P&O|       6|
# |           Cunard|       3|
# |Regent_Seven_Seas|       5|
# |              MSC|       8|
# |         Carnival|      22|
# |          Crystal|       2|
# |           Orient|       1|
# |         Princess|      17|
# |        Silversea|       4|
# |         Seabourn|       3|
# | Holland_American|      14|
# |         Windstar|       3|
# |           Disney|       2|
# |        Norwegian|      13|
# |          Oceania|       3|
# |          Azamara|       2|
# |        Celebrity|      10|
# |             Star|       6|
# |  Royal_Caribbean|      23|
# +-----------------+--------+

# %% [markdown]
# ### Preprocessing

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder

# %%
trainDF, testDF = crew_df.randomSplit([.8,.2],seed=42)
print(f"There are {trainDF.count()} rows in the training set, and {testDF.count()} in the test set")
# Out:
# There are 133 rows in the training set, and 25 in the test set

# %%
numeric_features = [feature for (feature, data_type) in trainDF.dtypes if data_type != 'string' and feature != 'crew']
numeric_features
# Out:
# ['Age', 'Tonnage', 'passengers', 'length', 'cabins', 'passenger_density']

# %%
stringIndexer = StringIndexer(inputCol='Cruise_line',
                             outputCol='Index_Cruise_line',
                             handleInvalid='skip')

# %% [markdown]
# ### OneHotEncoder

# %%
ohe = OneHotEncoder(inputCol='Index_Cruise_line',
                    outputCol='ohe_Cruise_line')

# %% [markdown]
# gathering the numeric with ohe_transformation

# %%
vec_features = numeric_features + ['ohe_Cruise_line']

# %%
vec_features
# Out:
# ['Age',
#  'Tonnage',
#  'passengers',
#  'length',
#  'cabins',
#  'passenger_density',
#  'ohe_Cruise_line']

# %% [markdown]
# ###Use VectorAssembler to merge all columns into one column:

# %%
from pyspark.ml.feature import VectorAssembler

# %%
assembler = VectorAssembler(inputCols=vec_features, outputCol='features')

# %% [markdown]
# ### Create a Linear Regression Model

# %%
from pyspark.ml.regression import LinearRegression

# %%
lr = LinearRegression(featuresCol='features', labelCol='crew')

# %% [markdown]
# ### Creating a Pipeline

# %%
from pyspark.ml import Pipeline

# %%
pipeline = Pipeline(stages=[stringIndexer, ohe, assembler, lr])

# %%
pip_model = pipeline.fit(trainDF)
predictions_df = pip_model.transform(testDF)

# %% [markdown]
# ### Model Evaluation

# %%
from pyspark.ml.evaluation import RegressionEvaluator

# %%
regressionEvaluator = RegressionEvaluator(predictionCol='prediction',
                                         labelCol='crew',
                                         metricName='rmse')

# %%
rmse = regressionEvaluator.evaluate(predictions_df)
print(f"RMSE is {rmse:.1f}")
# Out:
# RMSE is 0.5

# %% [markdown]
# By Eng. Mostafa Nabieh
# If you have questions, please feel free to ask.
#
# My Email : nabieh.mostafa@yahoo.com
#
# My Whatsapp : +201015197566
